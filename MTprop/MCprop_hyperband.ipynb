# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cu118

# Transformers, CLIP, and other libs
# !pip install transformers tqdm scipy pandas scikit-learn pyarrow
# !pip install git+https://github.com/openai/CLIP.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu118
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 120.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 97.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 55.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 43.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 20.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 98.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# !pip install -U ray[tune]
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 9.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.5/68.5 MB 36.6 MB/s eta 0:00:00
# ...

# %%
import pandas as pd

feather_path = '/content/drive/MyDrive/CLIP_train1/data_reformat/train/full/train_data.feather'

df = pd.read_feather(feather_path)

print("📊 文件结构如下：")
print(df.info())

print("\n📝 前几行数据示例：")
print(df.head())
# Out:
# 📊 文件结构如下：
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4332 entries, 0 to 4331
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   passage_id     4332 non-null   object
#  1   folder_name    4332 non-null   object
#  2   title          4332 non-null   object
#  3   text           4332 non-null   object
#  4   combined_text  4332 non-null   object
# dtypes: object(5)
# memory usage: 169.3+ KB
# None
#
# 📝 前几行数据示例：
#                        passage_id                     folder_name  \
# 0  Battle_of_the_Eastern_Solomons  Battle_of_the_Eastern_Solomons
# 1                       Meshuggah                       Meshuggah
# 2                     Chris_Gragg                     Chris_Gragg
# 3                    Bobby_Gibbes                    Bobby_Gibbes
# 4                  Neville_Cardus                  Neville_Cardus
#
#                             title  \
# 0  Battle of the Eastern Solomons
# ...

# %%
# !python /content/drive/MyDrive/CLIP_train1/config_search.py
# Out:
# 2025-05-09 22:36:56.784596: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-09 22:36:56.801489: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746830216.822851    2754 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746830216.829250    2754 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
#%%time
#!python /content/drive/MyDrive/CLIP_train1/train.py \
  #--data_dir /content/drive/MyDrive/CLIP_train1/data_reformat \
  #--config /content/drive/MyDrive/CLIP_train1/config/MCProp_imgs_text.yaml \
  #--img_cache /content/drive/MyDrive/CLIP_train1/data_reformat/mapped_image_features.json \
  #--train_subfolder full \
  #--num_epochs 30 \
  #--logger_name /content/drive/MyDrive/CLIP_train1/runs/test
